# %% [markdown]
# ## Download PDFs

# %%
# !wget https://www.osce.org/files/f/documents/6/c/499414.pdf -O ./pdf/en1.pdf # English
# !wget https://www.osce.org/files/f/documents/9/d/499420.pdf -O ./pdf/sh1.pdf # Shqip
# !wget https://www.osce.org/files/f/documents/4/e/499423.pdf -O ./pdf/ma1.pdf # Македонски

# %% [markdown]
# ## Import packages

# %%
import sys
sys.path.append('../')

from pathlib import Path
from src.utils import (extract_text,
                      remove_footnotes)

# %% [markdown]
# ## Test Codes

# %%
raw_text    = extract_text(Path('./pdf/ma1.pdf'))
text_nofoot = remove_footnotes(raw_text, 0, 0, UNTIL_END=True, CHECK_OUTPUT=True)
# Out:
# Page Number: 0
#
# Page Number: 1
#
# Removed Footenotes:
#
# 1   Види го Претходните извештаи на ОДИХР за Северна Македонија
#
# --------------------------NEW PAGE----------------------------
#
#
# Page Number: 2
#
# Removed Footenotes:
#
# 2   Во моментов, од 80 општини и Градот Скопје, СДСМ има 57 градоначалнички места, Демократската
# унија за интеграција (ДУИ) на етничките Албанци, има 10, Внатрешната македонска револуционерна
# организација – Демократска партија за македонско национално единство (ВМРО-ДПМНЕ) има 5, а
# Алијансата на Албанците (АА) има 3, додека 3 градоначалници се независни. Демократската партија на
# Албанците (ДПА), етничкото албанско Движење БЕСА (БЕСА) и Демократската партија на Турците во
# Македонија (ДПТМ) имаат по една градоначалничка позиција.
# 3   Сегашната влада исто така опфаќа по еден министер од Движењето БЕСА (БЕСА) и Либерално-
# демократската партија (ЛДП). Коалицијата предводена од СДСМ, што победи на парламентарните
# ...
